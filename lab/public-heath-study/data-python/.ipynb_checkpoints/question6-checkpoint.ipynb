# %%
import pandas as pd
import numpy as np



vegetauxCsv = pd.read_csv("/Users/yassine/Desktop/data-python/fr_vegetaux.csv")
dateV = vegetauxCsv.loc[vegetauxCsv['Année'] == 2013]
r = dateV[dateV['Unité'] == 'Kcal/personne/jour']
perDayV = r[r['Élément'] == 'Disponibilité alimentaire (Kcal/personne/jour)']
rcpVegetaux = perDayV.drop(['Année','Code Produit','Symbole','Domaine','Code Domaine','Code Élément','Code année','Description du Symbole'], axis=1)


rcpVegetaux['Valeur'].sum()
# Out:
# 401166.0

# %%
# Out:
#        Code zone                Zone  \
# 8              2         Afghanistan
# 18             2         Afghanistan
# 30             2         Afghanistan
# 42             2         Afghanistan
# 51             2         Afghanistan
# ...          ...                 ...
# 3757           8  Antigua-et-Barbuda
# 4238         194     Arabie saoudite
# 8631          16          Bangladesh
# 8869          16          Bangladesh
# 50169        105              Israël
#
#                                               Élément               Produit  \
# 8      Disponibilité alimentaire (Kcal/personne/jour)                   Blé
# 18     Disponibilité alimentaire (Kcal/personne/jour)      Riz (Eq Blanchi)
# 30     Disponibilité alimentaire (Kcal/personne/jour)                  Orge
# 42     Disponibilité alimentaire (Kcal/personne/jour)                  Maïs
# 51     Disponibilité alimentaire (Kcal/personne/jour)                Millet
# ...                                               ...                   ...
# 3757   Disponibilité alimentaire (Kcal/personne/jour)  Graines de tournesol
# 4238   Disponibilité alimentaire (Kcal/personne/jour)          Sucre, canne
# 8631   Disponibilité alimentaire (Kcal/personne/jour)  Sucre non centrifugé
# 8869   Disponibilité alimentaire (Kcal/personne/jour)   Huile de Son de Riz
# 50169  Disponibilité alimentaire (Kcal/personne/jour)      Graines de coton
#
#                     Unité  Valeur
# 8      Kcal/personne/jour  1369.0
# 18     Kcal/personne/jour   141.0
# 30     Kcal/personne/jour    26.0
# 42     Kcal/personne/jour    21.0
# 51     Kcal/personne/jour     3.0
# ...                   ...     ...
# 3757   Kcal/personne/jour     0.0
# 4238   Kcal/personne/jour     0.0
# 8631   Kcal/personne/jour    16.0
# 8869   Kcal/personne/jour     0.0
# 50169  Kcal/personne/jour     0.0
#
# [74 rows x 6 columns]

# %%
# Out:
# 8                         Blé
# 18           Riz (Eq Blanchi)
# 30                       Orge
# 42                       Maïs
# 51                     Millet
#                  ...
# 3757     Graines de tournesol
# 4238             Sucre, canne
# 8631     Sucre non centrifugé
# 8869      Huile de Son de Riz
# 50169        Graines de coton
# Name: Produit, Length: 74, dtype: object
# 8                         Blé
# 18           Riz (Eq Blanchi)
# 30                       Orge
# 42                       Maïs
# 51                     Millet
#                  ...
# 3757     Graines de tournesol
# 4238             Sucre, canne
# 8631     Sucre non centrifugé
# 8869      Huile de Son de Riz
# 50169        Graines de coton
# Name: Produit, Length: 74, dtype: object
# 8                         Blé
# 18           Riz (Eq Blanchi)
# 30                       Orge
# 42                       Maïs
# 51                     Millet
#                  ...
# 3757     Graines de tournesol
# 4238             Sucre, canne
# 8631     Sucre non centrifugé
# 8869      Huile de Son de Riz
# 50169        Graines de coton
# Name: Produit, Length: 74, dtype: object
# 8                         Blé
# 18           Riz (Eq Blanchi)
# 30                       Orge
# 42                       Maïs
# 51                     Millet
#                  ...
# 3757     Graines de tournesol
# 4238             Sucre, canne
# 8631     Sucre non centrifugé
# 8869      Huile de Son de Riz
# 50169        Graines de coton
# Name: Produit, Length: 74, dtype: object
# 8                         Blé
# 18           Riz (Eq Blanchi)
# 30                       Orge
# 42                       Maïs
# 51                     Millet
#                  ...
# 3757     Graines de tournesol
# 4238             Sucre, canne
# 8631     Sucre non centrifugé
# 8869      Huile de Son de Riz
# 50169        Graines de coton
# Name: Produit, Length: 74, dtype: object
# 8                         Blé
# 18           Riz (Eq Blanchi)
# 30                       Orge
# 42                       Maïs
# 51                     Millet
#                  ...
# 3757     Graines de tournesol
# 4238             Sucre, canne
# 8631     Sucre non centrifugé
# 8869      Huile de Son de Riz
# 50169        Graines de coton
# Name: Produit, Length: 74, dtype: object

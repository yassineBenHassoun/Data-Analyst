# %%
import pandas as pd
import numpy as np

populationCsvToArray = pd.read_csv("/Users/yassine/Desktop/data-python/fr_population.csv", sep=',')
populationBydate = populationCsvToArray.loc[populationCsvToArray['Année'] == 2013]
filtered_df = populationBydate[(populationBydate['Code zone'] != 96) & (populationBydate['Code zone'] != 41) & (populationBydate['Code zone'] != 128) & (populationBydate['Code zone'] != 214)]
populationRemoveDuplicateByCountries =  filtered_df.drop_duplicates(subset='Code zone', keep="last")
populationRemoveDuplicateByCountries.rename(columns={'Zone':'Pays'}, inplace=True)
dropPop = populationRemoveDuplicateByCountries.drop(['Élément','Code Produit','Symbole','Domaine','Code Domaine','Code Élément','Code année','Description du Symbole'], axis=1)
dropPop['Population'] = dropPop['Valeur'] * 1000
countries = dropPop

animauxCsv = pd.read_csv("/Users/yassine/Desktop/data-python/fr_animaux.csv", sep=',')
animauxCsv.loc[animauxCsv['Année'] == 2013]
animaux = animauxCsv.drop(['Année','Code Produit','Symbole','Domaine','Code Domaine','Code Élément','Code année','Description du Symbole'], axis=1)
animaux.rename(columns={'Valeur':'proteine'}, inplace=True)
animaux.rename(columns={'Zone':'Pays'}, inplace=True)


animauxGrammesperD = animaux[animaux['Élément'] == 'Disponibilité de protéines en quantité (g/personne/jour)']
animauxCaloriesPerD = animaux[animaux['Élément'] == 'Disponibilité alimentaire (Kcal/personne/jour)']

dataframeQuantities = animauxGrammesperD.merge(animauxCaloriesPerD, on='Code zone',suffixes=('_g/p/j', '_kcal/p/j'))

animauxPopulation = dataframeQuantities.merge(countries, on='Code zone')
animauxPopulation['food_supply_kg'] = animauxPopulation["proteine_g/p/j"] * 0.001 * animauxPopulation["Population"] * 365  
animauxPopulation["food_supply_kcal"] = animauxPopulation["proteine_kcal/p/j"] * animauxPopulation["Population"] * 365
animauxPopulation["ratio_kcal/kg"] =  animauxPopulation["food_supply_kcal"] / animauxPopulation['food_supply_kg']
animauxPopulation.dropna()

result = animauxPopulation.loc[animauxPopulation['proteine_g/p/j'] > 0.1]
ratioData = result.loc[result['ratio_kcal/kg'] > 0]

ratioData
# Out:
#        Code zone   Pays_g/p/j  \
# 0              2  Afghanistan
# 1              2  Afghanistan
# 2              2  Afghanistan
# 3              2  Afghanistan
# 4              2  Afghanistan
# ...          ...          ...
# 76998        181     Zimbabwe
# 77001        181     Zimbabwe
# 77002        181     Zimbabwe
# 77003        181     Zimbabwe
# 77005        181     Zimbabwe
#
#                                            Élément_g/p/j        Produit_g/p/j  \
# 0      Disponibilité de protéines en quantité (g/pers...     Viande de Bovins
# 1      Disponibilité de protéines en quantité (g/pers...     Viande de Bovins
# 2      Disponibilité de protéines en quantité (g/pers...     Viande de Bovins
# 3      Disponibilité de protéines en quantité (g/pers...     Viande de Bovins
# 4      Disponibilité de protéines en quantité (g/pers...     Viande de Bovins
# ...                                                  ...                  ...
# 76998  Disponibilité de protéines en quantité (g/pers...  Poissons Pelagiques
# 77001  Disponibilité de protéines en quantité (g/pers...  Poissons Pelagiques
# 77002  Disponibilité de protéines en quantité (g/pers...  Poissons Pelagiques
# 77003  Disponibilité de protéines en quantité (g/pers...  Poissons Pelagiques
# 77005  Disponibilité de protéines en quantité (g/pers...  Poissons Pelagiques
#
#            Unité_g/p/j  proteine_g/p/j Pays_kcal/p/j  \
# 0      g/personne/jour            1.89   Afghanistan
# 1      g/personne/jour            1.89   Afghanistan
# 2      g/personne/jour            1.89   Afghanistan
# 3      g/personne/jour            1.89   Afghanistan
# 4      g/personne/jour            1.89   Afghanistan
# ...                ...             ...           ...
# 76998  g/personne/jour            0.19      Zimbabwe
# 77001  g/personne/jour            0.19      Zimbabwe
# 77002  g/personne/jour            0.19      Zimbabwe
# 77003  g/personne/jour            0.19      Zimbabwe
# 77005  g/personne/jour            0.19      Zimbabwe
#
#                                      Élément_kcal/p/j        Produit_kcal/p/j  \
# 0      Disponibilité alimentaire (Kcal/personne/jour)        Viande de Bovins
# 1      Disponibilité alimentaire (Kcal/personne/jour)  Viande d'Ovins/Caprins
# 2      Disponibilité alimentaire (Kcal/personne/jour)     Viande de Volailles
# 3      Disponibilité alimentaire (Kcal/personne/jour)           Viande, Autre
# 4      Disponibilité alimentaire (Kcal/personne/jour)        Abats Comestible
# ...                                               ...                     ...
# 76998  Disponibilité alimentaire (Kcal/personne/jour)  Graisses Animales Crue
# 77001  Disponibilité alimentaire (Kcal/personne/jour)                   Oeufs
# 77002  Disponibilité alimentaire (Kcal/personne/jour)      Lait - Excl Beurre
# 77003  Disponibilité alimentaire (Kcal/personne/jour)      Poissons Eau Douce
# 77005  Disponibilité alimentaire (Kcal/personne/jour)     Poissons Pelagiques
#
#            Unité_kcal/p/j  proteine_kcal/p/j         Pays     Produit  Année  \
# 0      Kcal/personne/jour               27.0  Afghanistan  Population   2013
# 1      Kcal/personne/jour               31.0  Afghanistan  Population   2013
# 2      Kcal/personne/jour                9.0  Afghanistan  Population   2013
# 3      Kcal/personne/jour                1.0  Afghanistan  Population   2013
# 4      Kcal/personne/jour                5.0  Afghanistan  Population   2013
# ...                   ...                ...          ...         ...    ...
# 76998  Kcal/personne/jour               25.0     Zimbabwe  Population   2013
# 77001  Kcal/personne/jour                6.0     Zimbabwe  Population   2013
# 77002  Kcal/personne/jour               49.0     Zimbabwe  Population   2013
# 77003  Kcal/personne/jour                4.0     Zimbabwe  Population   2013
# 77005  Kcal/personne/jour                1.0     Zimbabwe  Population   2013
#
#                 Unité  Valeur  Population  food_supply_kg  food_supply_kcal  \
# 0      1000 personnes   30552    30552000      21076297.2      3.010900e+11
# 1      1000 personnes   30552    30552000      21076297.2      3.456959e+11
# 2      1000 personnes   30552    30552000      21076297.2      1.003633e+11
# 3      1000 personnes   30552    30552000      21076297.2      1.115148e+10
# 4      1000 personnes   30552    30552000      21076297.2      5.575740e+10
# ...               ...     ...         ...             ...               ...
# 76998  1000 personnes   14150    14150000        981302.5      1.291188e+11
# 77001  1000 personnes   14150    14150000        981302.5      3.098850e+10
# 77002  1000 personnes   14150    14150000        981302.5      2.530728e+11
# 77003  1000 personnes   14150    14150000        981302.5      2.065900e+10
# 77005  1000 personnes   14150    14150000        981302.5      5.164750e+09
#
#        ratio_kcal/kg
# 0       14285.714286
# 1       16402.116402
# 2        4761.904762
# 3         529.100529
# 4        2645.502646
# ...              ...
# 76998  131578.947368
# 77001   31578.947368
# 77002  257894.736842
# 77003   21052.631579
# 77005    5263.157895
#
# [29131 rows x 20 columns]

# %%
dt = []
# Out:
# <ipython-input-11-0d767e702f83>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratioData['rank'] =  col.rank()

# %%
newDataFrame = ratioData.filter(['Pays','Produit_g/p/j','Produit_kcal/p/j','food_supply_kg','food_supply_kcal','ratio_kcal/kg'], axis=1)

column = newDataFrame["ratio_kcal/kg"].astype(float)
newDataFrame['Rank'] = (column).astype(float).rank(method='dense', ascending=False).astype(float)


ratioByRank = newDataFrame.sort_values('Rank')

ratioByRank

#poser une question pourquoi il y a less deux valeurs Produit_g/p/j 	Produit_kcal/p/j
# Out:
#              Pays        Produit_g/p/j        Produit_kcal/p/j  \
# 25552    Finlande         Beurre, Ghee      Lait - Excl Beurre
# 56099    Pays-Bas         Cephalopodes      Lait - Excl Beurre
# 48364  Monténégro            Crustacés      Lait - Excl Beurre
# 35049     Islande         Beurre, Ghee      Lait - Excl Beurre
# 68062       Suède         Beurre, Ghee      Lait - Excl Beurre
# ...           ...                  ...                     ...
# 48264  Monténégro   Lait - Excl Beurre               Crustacés
# 44708    Maldives  Poissons Pelagiques      Mollusques, Autres
# 44702    Maldives  Poissons Pelagiques      Poissons Eau Douce
# 44698    Maldives  Poissons Pelagiques  Graisses Animales Crue
# 44697    Maldives  Poissons Pelagiques                   Crème
#
#        food_supply_kg  food_supply_kcal  ratio_kcal/kg     Rank
# 25552       237658.80      1.006089e+12   4.233333e+06      1.0
# 56099       672873.85      2.813836e+12   4.181818e+06      2.0
# 48364        31733.10      1.165058e+11   3.671429e+06      3.0
# 35049        18067.50      6.516345e+10   3.606667e+06      4.0
# 68062       384275.65      1.365925e+12   3.554545e+06      5.0
# ...               ...               ...            ...      ...
# 48264      6858882.90      2.266650e+08   3.304693e+01  14892.0
# 44708      6922097.25      1.259250e+08   1.819174e+01  14893.0
# 44702      6922097.25      1.259250e+08   1.819174e+01  14893.0
# 44698      6922097.25      1.259250e+08   1.819174e+01  14893.0
# 44697      6922097.25      1.259250e+08   1.819174e+01  14893.0
#
# [29131 rows x 7 columns]

# %%
col1 = r["ratio_prot"].astype(float) 
col2 = r["ratio_vege"].astype(float)
r['Rank'] = (col1+col2).astype(float).rank(method='dense', ascending=False).astype(float)
r.sort_values('Rank')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-db1411fb7cf1> in <module>
# ----> 1 col1 = r["ratio_prot"].astype(float)
#       2 col2 = r["ratio_vege"].astype(float)
#       3 r['Rank'] = (col1+col2).astype(float).rank(method='dense', ascending=False).astype(float)
#       4 r.sort_values('Rank')
#
# NameError: name 'r' is not defined
